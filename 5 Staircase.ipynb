# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def staircase(n):
    for i in range(1, n+1):
        print(" " * (n-i) + '#'*i)

        
# number of staircases
n = int(input().strip())
staircase(n)
# Out:
# 5
#     #
#    ##
#   ###
#  ####
# #####

# %%
def staircase(n):
    for i in range(n+1):
        print("#"* (n-i))

        
# number of staircases
n = int(input().strip())
staircase(n)
# Out:
# 5
# #####
# ####
# ###
# ##
# #

# %%
def staircase(n):
    for i in range(n+1):
        print("#"*i)

        
# number of staircases
n = int(input().strip())
staircase(n)
# Out:
# 5
#
# #
# ##
# ###
# ####
# #####
